# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Lets use the Cobb-Douglas function:
#
# $$
# Y = K^\alpha \cdot L^{1-\alpha}
# $$
#
# The function is widespread in economic classes because of its easy use, and analytical properties. The log-linearisation allows for a straight interpretation of output-elasticity. The Elasticity of Substitution is 1.
#
# $$
# \ln Y = \alpha\,\ln K + (1-\alpha)\,\ln L
# $$

# %%
# Define Cobb-Douglas function
def f(K, L, alpha):
    return K**alpha * L**(1 - alpha)

# Parameters
alpha = 0.3  # Capital share of income 
K = np.linspace(1, 100, 100)  # Capital stock
L = np.linspace(1, 100, 100)  # Labor input 
K, L = np.meshgrid(K, L)  # Create a meshgrid for K and L

Y = f(K,L, alpha = 0.25)

# %%
# Erstelle den 3D-Plot
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Zeichne die Oberfläche und füge eine Colorbar hinzu
surf = ax.plot_surface(K, L, Y, cmap='viridis', alpha=0.7, edgecolor='none')
cbar = fig.colorbar(surf, shrink=0.5, aspect=5)  # Die Colorbar zeigt die Werte von Y
cbar.set_label('Output (Y)')  # Beschriftung der Colorbar

# Achsenbeschriftungen und Titel
ax.set_xlabel('Capital (K)')
ax.set_ylabel('Labour (L)')
ax.set_zlabel('Output (Y)')
ax.set_title('Cobb-Douglas Production Function')

plt.show()

# %%
# Set Budget Constraint
def Constraint(K, w, r, L, I):
    return (w * L + r * K = I)

# Set Parameters for Budget Constraint
w = 1  # Wage rate
r = 1  # Rental rate of capital   
I = 100  # Income

# Create a grid for K and L
K = np.linspace(1, 100, 100)  # Capital stock
L = np.linspace(1, 100, 100)  # Labor input
K, L = np.meshgrid(K, L)  # Create a meshgrid for K and L

# Calculate the budget constraint
B = Constraint(K, w, r, L, I)
# Out:
#   Cell In[7], line 3
#     return (w * L + r * K = I)
#             ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?
